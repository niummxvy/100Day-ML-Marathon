# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %% [markdown]
# Hidden Layers = 2, Neuron = 6 (4,2)
#
# Test loss = 0.017, Training loss = 0.017

# %%
from PIL import Image
import matplotlib.pyplot as plt
img1 = Image.open('./test1.png')
plt.figure(figsize=(20,15))
plt.imshow(img1)
plt.show()

# %% [markdown]
# Hidden Layers = 1, Neuron = 8 (8)
#
# Test loss = 0.015, Training loss = 0.014

# %%
img2 = Image.open('./test2.png')
plt.figure(figsize=(20,15))
plt.imshow(img2)
plt.show()

# %% [markdown]
# Hidden Layers = 3, Neuron = 8 (4,4)
#
# Test loss = 0.013, Training loss = 0.013

# %%
img3 = Image.open('./test3.png')
plt.figure(figsize=(20,15))
plt.imshow(img3)
plt.show()

# %% [markdown]
# Hidden Layers = 5, Neuron = 8 (2,2,2,2)
#
# Test loss = 0.030, Training loss = 0.031

# %%
img4 = Image.open('./test4.png')
plt.figure(figsize=(20,15))
plt.imshow(img4)
plt.show()
